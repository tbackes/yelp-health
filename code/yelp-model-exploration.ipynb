# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import re
import string
import json
pd.options.mode.chained_assignment = None  # default='warn'
from merge_main import open_pickle, save_to_pickle
from import_yelp_mongo import get_yelp_reviews, get_yelp_reviews_afterdate

# %matplotlib inline
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.svm import SVC, SVR
from sklearn.svm import LinearSVC, LinearSVR
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score,\
                            confusion_matrix, classification_report, mean_squared_error
from sklearn.grid_search import GridSearchCV
import yelp_tfidf as lib_tfidf
import model_phoenix as lib
# Out:
# /Users/tracy/anaconda/lib/python2.7/site-packages/fuzzywuzzy/fuzz.py:33: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
from IPython.display import display

# %%
reload(lib)
# Out:
# <module 'model_phoenix' from 'model_phoenix.py'>

# %% [markdown]
# # Model, Create X, y:

# %% [markdown]
# # Phoenix, AZ -- Classification:

# %%
# %%time
df_AZ, tfs, tfs_vocab, tfs_h, tfs_h_vocab, A_labels, A_vocab = lib.unpack_data('../data/phx/model_data_phx.pkl')

col1 = ['rev_ct','neg_ct','stars_avg','rev_len_avg','stars_var']
col2 = ['rev_ct','neg_ct','stars_avg','rev_len_avg','stars_var','n_hygiene','n_service',
        'n_location','n_food','n_premise','n_quality','n_value']

HM = lib.HealthModel(df_AZ, tfs, tfs_h, tfs_vocab=tfs_vocab, tfs_h_vocab=tfs_h_vocab)
# Out:
# CPU times: user 24.1 s, sys: 4.25 s, total: 28.3 s
# Wall time: 38 s

# %%
df_AZ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23487 entries, 0 to 23486
# Data columns (total 31 columns):
# business_id       23487 non-null object
# id_               23487 non-null object
# date              23487 non-null object
# inspec_id         23487 non-null object
# n_priority        23487 non-null object
# grade             23487 non-null object
# purpose           23487 non-null object
# n_violations      16427 non-null float64
# v_core            23487 non-null int64
# sum_core          23487 non-null int64
# v_foundation      23487 non-null int64
# sum_foundation    23487 non-null int64
# v_priority        23487 non-null int64
# sum_priority      23487 non-null int64
# date_start        23487 non-null datetime64[ns]
# rev_ct            23487 non-null int64
# neg_ct            23487 non-null int64
# stars_avg         23487 non-null float64
# rev_len_avg       23487 non-null float64
# stars_var         23487 non-null float64
# text              23487 non-null object
# aspects           23487 non-null object
# sentences         23487 non-null object
# hygiene_text      23487 non-null object
# n_food            23487 non-null float64
# n_hygiene         23487 non-null float64
# n_location        23487 non-null float64
# n_premise         23487 non-null float64
# n_quality         23487 non-null float64
# n_service         23487 non-null float64
# n_value           23487 non-null float64
# dtypes: datetime64[ns](1), float64(11), int64(8), object(11)
# memory usage: 5.7+ MB

# %%
model_rfc = RandomForestClassifier(oob_score=True, 
                                   random_state = 981, 
                                   class_weight='balanced',
                                   n_jobs=-1)
model_log = LogisticRegression(class_weight='balanced', n_jobs=-1, random_state=981)
model_svc = LinearSVC(C=0.19, random_state = 981, class_weight='balanced')

models_unoptimized_c = [model_rfc, model_log, model_svc]

# %%
model_rfr = RandomForestRegressor(oob_score=True, 
                                  random_state = 981,
                                  max_features='sqrt',
                                  n_jobs=-1)
model_lin = LinearRegression(n_jobs=-1)
model_svr = LinearSVR(C=0.19, random_state = 981)

# %% [markdown]
# ## RELOAD CODE

# %%
reload(lib)

HM = lib.HealthModel(df_AZ, tfs, tfs_h, tfs_vocab=tfs_vocab, tfs_h_vocab=tfs_h_vocab)

# %% [markdown]
# ### Models Using Original Features

# %% [markdown]
# #### Un-optimized

# %%
# %%time
models = [model_rfc, model_log, model_svc]

# Unoptimized, original features
display(HM.compare_models(models, ['unoptimized' for _ in models], ['Original Features' for _ in models], col=col1))
# Out:
#                 FN    FP    TN    TP  accuracy        f1       mse  precision  \
# sum_priority
# 1             1903  1370  2728  1046  0.535547  0.389935  0.464453   0.432947
# 2              944   455  5567    81  0.801476  0.103780  0.198524   0.151119
# 3              331   104  6609     3  0.938272  0.013605  0.061728   0.028037
# 4               95    18  6933     1  0.983965  0.017391  0.016035   0.052632
# 5               23     5  7019     0  0.996027  0.000000  0.003973   0.000000
# 6                7     1  7039     0  0.998865  0.000000  0.001135   0.000000
# 1             1631  1618  2480  1318  0.538953  0.447918  0.461047   0.448910
# 2              526  2569  3453   499  0.560806  0.243831  0.439194   0.162647
# 3              169  2877  3836   165  0.567759  0.097749  0.432241   0.054241
# 4               48  2994  3957    48  0.568327  0.030593  0.431673   0.015779
# 5                7  2902  4122    16  0.587200  0.010881  0.412800   0.005483
# 6                3  2368  4672     4  0.663545  0.003363  0.336455   0.001686
# 1             2949     0  4098     0  0.581524  0.000000  0.418476   0.000000
# 2               28  5772   250   997  0.176955  0.255838  0.823045   0.147289
# 3               30  5864   849   304  0.163616  0.093510  0.836384   0.049287
# 4               96     0  6951     0  0.986377  0.000000  0.013623   0.000000
# 5               23     0  7024     0  0.996736  0.000000  0.003264   0.000000
# 6                7     0  7040     0  0.999007  0.000000  0.000993   0.000000
#
#                 recall                   model         type           features
# sum_priority
# 1             0.354697  RandomForestClassifier  unoptimized  Original Features
# 2             0.079024  RandomForestClassifier  unoptimized  Original Features
# 3             0.008982  RandomForestClassifier  unoptimized  Original Features
# 4             0.010417  RandomForestClassifier  unoptimized  Original Features
# 5             0.000000  RandomForestClassifier  unoptimized  Original Features
# 6             0.000000  RandomForestClassifier  unoptimized  Original Features
# 1             0.446931      LogisticRegression  unoptimized  Original Features
# 2             0.486829      LogisticRegression  unoptimized  Original Features
# 3             0.494012      LogisticRegression  unoptimized  Original Features
# 4             0.500000      LogisticRegression  unoptimized  Original Features
# 5             0.695652      LogisticRegression  unoptimized  Original Features
# 6             0.571429      LogisticRegression  unoptimized  Original Features
# 1             0.000000               LinearSVC  unoptimized  Original Features
# 2             0.972683               LinearSVC  unoptimized  Original Features
# 3             0.910180               LinearSVC  unoptimized  Original Features
# 4             0.000000               LinearSVC  unoptimized  Original Features
# 5             0.000000               LinearSVC  unoptimized  Original Features
# 6             0.000000               LinearSVC  unoptimized  Original Features
# CPU times: user 12.9 s, sys: 292 ms, total: 13.2 s
# Wall time: 13.6 s

# %% [markdown]
# #### Optimized (Gridsearch CV best parameters for `sum_priority >= 2`)

# %%
# %%time
models = [RandomForestClassifier(**{'class_weight': 'balanced',
                                     'criterion': 'gini',
                                     'max_depth': 4,
                                     'max_features': 'sqrt',
                                     'min_samples_leaf': 2,
                                     'n_estimators': 200,
                                     'random_state': 981,
                                     'n_jobs': -1})]#, 
#           model_log, model_svc]

# optimized, original features -- optimized w/ scoring = precision
display(HM.compare_models(models, ['optimized - precison' for _ in models], ['Original Features' for _ in models],  col=col1))
# Out:
#                 FN    FP    TN    TP  accuracy        f1       mse  precision  \
# sum_priority
# 1             1699  1513  2585  1250  0.544203  0.437675  0.455797   0.452407
# 2              540  2468  3554   485  0.573152  0.243841  0.426848   0.164240
# 3              166  2960  3753   168  0.556407  0.097054  0.443593   0.053708
# 4               47  2485  4466    49  0.640698  0.037262  0.359302   0.019337
# 5               15  1552  5472     8  0.777636  0.010107  0.222364   0.005128
# 6                7   176  6864     0  0.974032  0.000000  0.025968   0.000000
#
#                 recall                   model                  type  \
# sum_priority
# 1             0.423872  RandomForestClassifier  optimized - precison
# 2             0.473171  RandomForestClassifier  optimized - precison
# 3             0.502994  RandomForestClassifier  optimized - precison
# 4             0.510417  RandomForestClassifier  optimized - precison
# 5             0.347826  RandomForestClassifier  optimized - precison
# 6             0.000000  RandomForestClassifier  optimized - precison
#
#                        features
# sum_priority
# 1             Original Features
# 2             Original Features
# 3             Original Features
# 4             Original Features
# 5             Original Features
# 6             Original Features
# CPU times: user 20.8 s, sys: 1.06 s, total: 21.8 s
# Wall time: 11.8 s

# %%
models = [RandomForestClassifier(**{'class_weight': 'balanced',
                                     'criterion': 'gini',
                                     'max_depth': 10,
                                     'max_features': 'log2',
                                     'min_samples_leaf': 2,
                                     'n_estimators': 200,
                                     'random_state': 981,
                                     'n_jobs': -1})]#, 
#           model_log, model_svc]

# optimized, original features -- optimized w/ scoring = accuracy
display(HM.compare_models(models, ['optimized - accuracy' for _ in models], ['Original Features' for _ in models],  col=col1))
# Out:
#                 FN    FP    TN    TP  accuracy        f1       mse  precision  \
# sum_priority
# 1             1531  1705  2393  1418  0.540798  0.467062  0.459202   0.454051
# 2              727  1415  4607   298  0.696041  0.217677  0.303959   0.173964
# 3              283   820  5893    51  0.843479  0.084647  0.156521   0.058553
# 4               92   126  6825     4  0.969065  0.035398  0.030935   0.030769
# 5               23    23  7001     0  0.993472  0.000000  0.006528   0.000000
# 6                7     2  7038     0  0.998723  0.000000  0.001277   0.000000
#
#                 recall                   model                  type  \
# sum_priority
# 1             0.480841  RandomForestClassifier  optimized - accuracy
# 2             0.290732  RandomForestClassifier  optimized - accuracy
# 3             0.152695  RandomForestClassifier  optimized - accuracy
# 4             0.041667  RandomForestClassifier  optimized - accuracy
# 5             0.000000  RandomForestClassifier  optimized - accuracy
# 6             0.000000  RandomForestClassifier  optimized - accuracy
#
#                        features
# sum_priority
# 1             Original Features
# 2             Original Features
# 3             Original Features
# 4             Original Features
# 5             Original Features
# 6             Original Features

# %%
models = [RandomForestClassifier(**{'class_weight': 'balanced',
                                     'criterion': 'entropy',
                                     'max_depth': 2,
                                     'max_features': 'log2',
                                     'min_samples_leaf': 4,
                                     'n_estimators': 100,
                                     'random_state': 981,
                                     'n_jobs': -1})]#, 
#           model_log, model_svc]

# optimized, original features -- optimized w/ scoring = recall
display(HM.compare_models(models, ['optimized - recall' for _ in models], ['Original Features' for _ in models],  col=col1))
# Out:
#                 FN    FP    TN    TP  accuracy        f1       mse  precision  \
# sum_priority
# 1             1942  1208  2890  1007  0.553001  0.390008  0.446999   0.454628
# 2              504  2659  3363   521  0.551157  0.247800  0.448843   0.163836
# 3              139  3419  3294   195  0.495104  0.098784  0.504896   0.053957
# 4               35  3273  3678    61  0.530580  0.035569  0.469420   0.018296
# 5               10  3209  3815    13  0.543210  0.008012  0.456790   0.004035
# 6                6   878  6162     1  0.874557  0.002257  0.125443   0.001138
#
#                 recall                   model                type  \
# sum_priority
# 1             0.341472  RandomForestClassifier  optimized - recall
# 2             0.508293  RandomForestClassifier  optimized - recall
# 3             0.583832  RandomForestClassifier  optimized - recall
# 4             0.635417  RandomForestClassifier  optimized - recall
# 5             0.565217  RandomForestClassifier  optimized - recall
# 6             0.142857  RandomForestClassifier  optimized - recall
#
#                        features
# sum_priority
# 1             Original Features
# 2             Original Features
# 3             Original Features
# 4             Original Features
# 5             Original Features
# 6             Original Features

# %%
models = [RandomForestClassifier(**{'class_weight': 'balanced',
                                     'criterion': 'gini',
                                     'max_depth': 2,
                                     'max_features': 'sqrt',
                                     'min_samples_leaf': 4,
                                     'n_estimators': 200,
                                     'random_state': 981,
                                     'n_jobs': -1})]#, 
#           model_log, model_svc]

# optimized, original features -- optimized w/ scoring = f1 score
display(HM.compare_models(models, ['optimized - f1' for _ in models], ['Original Features' for _ in models],  col=col1))
# Out:
#                 FN    FP    TN    TP  accuracy        f1       mse  precision  \
# sum_priority
# 1             1943  1206  2892  1006  0.553143  0.389847  0.446857   0.454792
# 2              507  2629  3393   518  0.554988  0.248322  0.445012   0.164601
# 3              138  3484  3229   196  0.486022  0.097658  0.513978   0.053261
# 4               35  3262  3689    61  0.532141  0.035683  0.467859   0.018357
# 5               10  2930  4094    13  0.582801  0.008766  0.417199   0.004417
# 6                5   822  6218     2  0.882645  0.004813  0.117355   0.002427
#
#                 recall                   model            type  \
# sum_priority
# 1             0.341133  RandomForestClassifier  optimized - f1
# 2             0.505366  RandomForestClassifier  optimized - f1
# 3             0.586826  RandomForestClassifier  optimized - f1
# 4             0.635417  RandomForestClassifier  optimized - f1
# 5             0.565217  RandomForestClassifier  optimized - f1
# 6             0.285714  RandomForestClassifier  optimized - f1
#
#                        features
# sum_priority
# 1             Original Features
# 2             Original Features
# 3             Original Features
# 4             Original Features
# 5             Original Features
# 6             Original Features

# %% [markdown]
# ### Models using Original TFIDF feature matrix (5000 top words)

# %% [markdown]
# #### Unoptimized

# %%
# %%time
models = [model_rfc, model_log, model_svc]

# Unoptimized, tfidf features
display(HM.compare_models(models, ['unoptimized' for _ in models], ['Original TFIDF' for _ in models], tfs=True))
# Out:
#                 FN    FP    TN    TP  accuracy        f1       mse  precision  \
# sum_priority
# 1             2177   814  3284   772  0.575564  0.340463  0.424436   0.486759
# 2             1005    41  5981    20  0.851568  0.036832  0.148432   0.327869
# 3              333    10  6703     1  0.951327  0.005797  0.048673   0.090909
# 4               95     3  6948     1  0.986093  0.020000  0.013907   0.250000
# 5               23     2  7022     0  0.996452  0.000000  0.003548   0.000000
# 6                7     1  7039     0  0.998865  0.000000  0.001135   0.000000
# 1             1330  1680  2418  1619  0.572868  0.518246  0.427132   0.490755
# 2              558  1800  4222   467  0.665390  0.283718  0.334610   0.205999
# 3              231  1158  5555   103  0.802895  0.129154  0.197105   0.081681
# 4               80   419  6532    16  0.929190  0.060264  0.070810   0.036782
# 5               23   123  6901     0  0.979282  0.000000  0.020718   0.000000
# 6                7    30  7010     0  0.994750  0.000000  0.005250   0.000000
# 1             1350  1658  2440  1599  0.573152  0.515308  0.426848   0.490943
# 2              572  1774  4248   453  0.667092  0.278598  0.332908   0.203413
# 3              238  1076  5637    96  0.813538  0.127490  0.186462   0.081911
# 4               82   336  6615    14  0.940684  0.062780  0.059316   0.040000
# 5               23    67  6957     0  0.987229  0.000000  0.012771   0.000000
# 6                7    16  7024     0  0.996736  0.000000  0.003264   0.000000
#
#                 recall                   model         type        features
# sum_priority
# 1             0.261784  RandomForestClassifier  unoptimized  Original TFIDF
# 2             0.019512  RandomForestClassifier  unoptimized  Original TFIDF
# 3             0.002994  RandomForestClassifier  unoptimized  Original TFIDF
# 4             0.010417  RandomForestClassifier  unoptimized  Original TFIDF
# 5             0.000000  RandomForestClassifier  unoptimized  Original TFIDF
# 6             0.000000  RandomForestClassifier  unoptimized  Original TFIDF
# 1             0.549000      LogisticRegression  unoptimized  Original TFIDF
# 2             0.455610      LogisticRegression  unoptimized  Original TFIDF
# 3             0.308383      LogisticRegression  unoptimized  Original TFIDF
# 4             0.166667      LogisticRegression  unoptimized  Original TFIDF
# 5             0.000000      LogisticRegression  unoptimized  Original TFIDF
# 6             0.000000      LogisticRegression  unoptimized  Original TFIDF
# 1             0.542218               LinearSVC  unoptimized  Original TFIDF
# 2             0.441951               LinearSVC  unoptimized  Original TFIDF
# 3             0.287425               LinearSVC  unoptimized  Original TFIDF
# 4             0.145833               LinearSVC  unoptimized  Original TFIDF
# 5             0.000000               LinearSVC  unoptimized  Original TFIDF
# 6             0.000000               LinearSVC  unoptimized  Original TFIDF
# CPU times: user 1min 32s, sys: 32.2 s, total: 2min 4s
# Wall time: 1min 37s

# %% [markdown]
# #### Optimized (Gridsearch CV best parameters for `sum_priority >= 2`)

# %%
# %%time
models = [RandomForestClassifier(**{'class_weight': 'balanced',
                                     'criterion': 'gini',
                                     'max_depth': 10,
                                     'max_features': 'sqrt',
                                     'min_samples_leaf': 3,
                                     'n_estimators': 200,
                                     'n_jobs': -1,
                                     'random_state': 981
                                   })]#, 
          #model_log, model_svc]

# Optimized, tfidf features -- precision
display(HM.compare_models(models, ['optimized - precision' for _ in models], ['Original TFIDF' for _ in models],
                          tfs=True))
# Out:
#                 FN    FP    TN    TP  accuracy        f1       mse  precision  \
# sum_priority
# 1             1706  1257  2841  1243  0.579537  0.456231  0.420463   0.497200
# 2              929   301  5721    96  0.825458  0.135021  0.174542   0.241814
# 3              330    26  6687     4  0.949482  0.021978  0.050518   0.133333
# 4               95     3  6948     1  0.986093  0.020000  0.013907   0.250000
# 5               23     1  7023     0  0.996594  0.000000  0.003406   0.000000
# 6                7     1  7039     0  0.998865  0.000000  0.001135   0.000000
#
#                 recall                   model                   type  \
# sum_priority
# 1             0.421499  RandomForestClassifier  optimized - precision
# 2             0.093659  RandomForestClassifier  optimized - precision
# 3             0.011976  RandomForestClassifier  optimized - precision
# 4             0.010417  RandomForestClassifier  optimized - precision
# 5             0.000000  RandomForestClassifier  optimized - precision
# 6             0.000000  RandomForestClassifier  optimized - precision
#
#                     features
# sum_priority
# 1             Original TFIDF
# 2             Original TFIDF
# 3             Original TFIDF
# 4             Original TFIDF
# 5             Original TFIDF
# 6             Original TFIDF
# CPU times: user 8min 43s, sys: 23.1 s, total: 9min 6s
# Wall time: 3min 23s

# %%
# %%time
models = [RandomForestClassifier(**{'class_weight': 'balanced',
                                     'criterion': 'gini',
                                     'max_depth': 3,
                                     'max_features': 'sqrt',
                                     'min_samples_leaf': 2,
                                     'n_estimators': 200,
                                     'n_jobs': -1,
                                     'random_state': 981
                                   })]#, 
          #model_log, model_svc]

# Optimized, tfidf features -- f1 score
display(HM.compare_models(models, ['optimized - f1' for _ in models], ['Original TFIDF' for _ in models],
                          tfs=True))
# Out:
#                 FN    FP    TN    TP  accuracy        f1       mse  precision  \
# sum_priority
# 1             1588  1551  2547  1361  0.554562  0.464426  0.445438   0.467376
# 2              551  2140  3882   474  0.618135  0.260511  0.381865   0.181331
# 3              208  1777  4936   126  0.718320  0.112651  0.281680   0.066211
# 4               75   622  6329    21  0.901093  0.056834  0.098907   0.032659
# 5               23    10  7014     0  0.995317  0.000000  0.004683   0.000000
# 6                7     0  7040     0  0.999007  0.000000  0.000993   0.000000
#
#                 recall                   model            type        features
# sum_priority
# 1             0.461512  RandomForestClassifier  optimized - f1  Original TFIDF
# 2             0.462439  RandomForestClassifier  optimized - f1  Original TFIDF
# 3             0.377246  RandomForestClassifier  optimized - f1  Original TFIDF
# 4             0.218750  RandomForestClassifier  optimized - f1  Original TFIDF
# 5             0.000000  RandomForestClassifier  optimized - f1  Original TFIDF
# 6             0.000000  RandomForestClassifier  optimized - f1  Original TFIDF
# CPU times: user 3min 10s, sys: 16.2 s, total: 3min 26s
# Wall time: 1min 30s

# %% [markdown]
# ## Topic Segmentation (Classify topic of each sentence)

# %% [markdown]
# ### Models using Topic summary features:

# %% [markdown]
# #### Unoptimized

# %%
# %%time
models = [model_rfc, model_log, model_svc]

# Unoptimized, tfidf features
display(HM.compare_models(models, ['unoptimized' for _ in models], ['Topic features' for _ in models], col=col2))
# Out:
#                 FN   FP    TN   TP  accuracy        f1       mse  precision  \
# sum_priority
# 1             2641  343  3755  308  0.576557  0.171111  0.423443   0.473118
# 2             1022   36  5986    3  0.849865  0.005639  0.150135   0.076923
# 3              334   24  6689    0  0.949198  0.000000  0.050802   0.000000
# 4               96   12  6939    0  0.984674  0.000000  0.015326   0.000000
# 5               23    4  7020    0  0.996169  0.000000  0.003831   0.000000
# 6                7    1  7039    0  0.998865  0.000000  0.001135   0.000000
# 1             2420  629  3469  529  0.567334  0.257609  0.432666   0.456822
# 2              885  687  5335  140  0.776926  0.151188  0.223074   0.169287
# 3              305  545  6168   29  0.879381  0.063877  0.120619   0.050523
# 4               92  209  6742    4  0.957287  0.025890  0.042713   0.018779
# 5               23  100  6924    0  0.982546  0.000000  0.017454   0.000000
# 6                7   26  7014    0  0.995317  0.000000  0.004683   0.000000
# 1             2443  599  3499  506  0.568327  0.249630  0.431673   0.457919
# 2              898  645  5377  127  0.781042  0.141347  0.218958   0.164508
# 3              308  480  6233   26  0.888179  0.061905  0.111821   0.051383
# 4               92  168  6783    4  0.963105  0.029851  0.036895   0.023256
# 5               23   72  6952    0  0.986519  0.000000  0.013481   0.000000
# 6                7   15  7025    0  0.996878  0.000000  0.003122   0.000000
#
#                 recall                   model         type      features
# sum_priority
# 1             0.104442  RandomForestClassifier  unoptimized  Health TFIDF
# 2             0.002927  RandomForestClassifier  unoptimized  Health TFIDF
# 3             0.000000  RandomForestClassifier  unoptimized  Health TFIDF
# 4             0.000000  RandomForestClassifier  unoptimized  Health TFIDF
# 5             0.000000  RandomForestClassifier  unoptimized  Health TFIDF
# 6             0.000000  RandomForestClassifier  unoptimized  Health TFIDF
# 1             0.179383      LogisticRegression  unoptimized  Health TFIDF
# 2             0.136585      LogisticRegression  unoptimized  Health TFIDF
# 3             0.086826      LogisticRegression  unoptimized  Health TFIDF
# 4             0.041667      LogisticRegression  unoptimized  Health TFIDF
# 5             0.000000      LogisticRegression  unoptimized  Health TFIDF
# 6             0.000000      LogisticRegression  unoptimized  Health TFIDF
# 1             0.171584               LinearSVC  unoptimized  Health TFIDF
# 2             0.123902               LinearSVC  unoptimized  Health TFIDF
# 3             0.077844               LinearSVC  unoptimized  Health TFIDF
# 4             0.041667               LinearSVC  unoptimized  Health TFIDF
# 5             0.000000               LinearSVC  unoptimized  Health TFIDF
# 6             0.000000               LinearSVC  unoptimized  Health TFIDF
# CPU times: user 4min 19s, sys: 27.2 s, total: 4min 46s
# Wall time: 2min 11s

# %% [markdown]
# #### Optimized (Gridsearch CV best parameters for `sum_priority >= 2`)

# %%
# %%time
models = [RandomForestClassifier(**{'class_weight': 'balanced',
                                     'criterion': 'entropy',
                                     'max_depth': None,
                                     'max_features': 'sqrt',
                                     'min_samples_leaf': 2,
                                     'n_estimators': 200,
                                     'n_jobs': -1,
                                     'random_state': 981})]#, 
#           model_log, model_svc]

# Optimized, health tfidf features -- precision
display(HM.compare_models(models, ['optimized - precision' for _ in models], ['Topic features' for _ in models], 
                          col=col2))

# %%
# %%time
models = [RandomForestClassifier(**{'class_weight': 'balanced',
                                     'criterion': 'gini',
                                     'max_depth': 10,
                                     'max_features': 'sqrt',
                                     'min_samples_leaf': 2,
                                     'n_estimators': 200,
                                     'n_jobs': -1,
                                     'random_state': 981})]#, 
#           model_log, model_svc]

# Optimized, health tfidf features -- accuracy
display(HM.compare_models(models, ['optimized - accuracy' for _ in models], ['Topic features' for _ in models], 
                          col=col2))

# %%
# %%time
models = [RandomForestClassifier(**{'class_weight': 'balanced',
                                     'criterion': 'gini',
                                     'max_depth': 2,
                                     'max_features': 'sqrt',
                                     'min_samples_leaf': 4,
                                     'n_estimators': 100,
                                     'n_jobs': -1,
                                     'random_state': 981})]#, 
#           model_log, model_svc]

# Optimized, health tfidf features -- recall score
display(HM.compare_models(models, ['optimized - recall' for _ in models], ['Topic features' for _ in models], 
                          col=col2))

# %%
# %%
# models = [RandomForestClassifier(**{'class_weight': 'balanced',
#                                      'criterion': 'gini',
#                                      'max_depth': 2,
#                                      'max_features': 'sqrt',
#                                      'min_samples_leaf': 4,
#                                      'n_estimators': 200,
#                                      'n_jobs': -1,
#                                      'random_state': 981})]#,
# #           model_log, model_svc]
#
# # Optimized, health tfidf features -- f1 score
# display(HM.compare_models(models, ['optimized - f1' for _ in models], ['Topic features' for _ in models],
#                           col=col2))

# %% [markdown]
# ## Hygiene (Topic) Bag of Words (Vocab = Top 5000)

# %% [markdown]
# #### Unoptimized

# %%
# %%time
models = [model_rfc, model_log, model_svc]

# Unoptimized, tfidf features
display(HM.compare_models(models, ['unoptimized' for _ in models], ['Health TFIDF' for _ in models], tfs_h=True))
# Out:
#                 FN   FP    TN   TP  accuracy        f1       mse  precision  \
# sum_priority
# 1             2641  343  3755  308  0.576557  0.171111  0.423443   0.473118
# 2             1022   36  5986    3  0.849865  0.005639  0.150135   0.076923
# 3              334   24  6689    0  0.949198  0.000000  0.050802   0.000000
# 4               96   12  6939    0  0.984674  0.000000  0.015326   0.000000
# 5               23    4  7020    0  0.996169  0.000000  0.003831   0.000000
# 6                7    1  7039    0  0.998865  0.000000  0.001135   0.000000
# 1             2420  629  3469  529  0.567334  0.257609  0.432666   0.456822
# 2              885  687  5335  140  0.776926  0.151188  0.223074   0.169287
# 3              305  545  6168   29  0.879381  0.063877  0.120619   0.050523
# 4               92  209  6742    4  0.957287  0.025890  0.042713   0.018779
# 5               23  100  6924    0  0.982546  0.000000  0.017454   0.000000
# 6                7   26  7014    0  0.995317  0.000000  0.004683   0.000000
# 1             2443  599  3499  506  0.568327  0.249630  0.431673   0.457919
# 2              898  645  5377  127  0.781042  0.141347  0.218958   0.164508
# 3              308  480  6233   26  0.888179  0.061905  0.111821   0.051383
# 4               92  168  6783    4  0.963105  0.029851  0.036895   0.023256
# 5               23   72  6952    0  0.986519  0.000000  0.013481   0.000000
# 6                7   15  7025    0  0.996878  0.000000  0.003122   0.000000
#
#                 recall                   model
# sum_priority
# 1             0.104442  RandomForestClassifier
# 2             0.002927  RandomForestClassifier
# 3             0.000000  RandomForestClassifier
# 4             0.000000  RandomForestClassifier
# 5             0.000000  RandomForestClassifier
# 6             0.000000  RandomForestClassifier
# 1             0.179383      LogisticRegression
# 2             0.136585      LogisticRegression
# 3             0.086826      LogisticRegression
# 4             0.041667      LogisticRegression
# 5             0.000000      LogisticRegression
# 6             0.000000      LogisticRegression
# 1             0.171584               LinearSVC
# 2             0.123902               LinearSVC
# 3             0.077844               LinearSVC
# 4             0.041667               LinearSVC
# 5             0.000000               LinearSVC
# 6             0.000000               LinearSVC

# %% [markdown]
# #### Optimized (Gridsearch CV best parameters for `sum_priority >= 2`)

# %%
# %%time
models = [RandomForestClassifier(**{'class_weight': 'balanced',
                                     'criterion': 'gini',
                                     'max_depth': 3,
                                     'max_features': 'log2',
                                     'min_samples_leaf': 4,
                                     'n_estimators': 200,
                                     'n_jobs': -1,
                                     'random_state': 981})]#, model_log, model_svc]

# Optimized, health tfidf features -- precision
display(HM.compare_models(models, ['optimized - precision' for _ in models], ['Health TFIDF' for _ in models],
                          tfs_h=True))
# Out:
#                 FN   FP    TN   TP  accuracy        f1       mse  precision  \
# sum_priority
# 1             2289  746  3352  660  0.569320  0.303100  0.430680   0.469417
# 2              856  808  5214  169  0.763871  0.168831  0.236129   0.172979
# 3              290  675  6038   44  0.863062  0.083571  0.136938   0.061196
# 4               92  281  6670    4  0.947070  0.020997  0.052930   0.014035
# 5               23   97  6927    0  0.982971  0.000000  0.017029   0.000000
# 6                7    0  7040    0  0.999007  0.000000  0.000993   0.000000
#
#                 recall                   model
# sum_priority
# 1             0.223805  RandomForestClassifier
# 2             0.164878  RandomForestClassifier
# 3             0.131737  RandomForestClassifier
# 4             0.041667  RandomForestClassifier
# 5             0.000000  RandomForestClassifier
# 6             0.000000  RandomForestClassifier

# %%
# %%time
models = [RandomForestClassifier(**{'class_weight': 'balanced',
                                     'criterion': 'entropy',
                                     'max_depth': 2,
                                     'max_features': 'log2',
                                     'min_samples_leaf': 3,
                                     'n_estimators': 100,
                                     'n_jobs': -1,
                                     'random_state': 981})]#, model_log, model_svc]

# Optimized, health tfidf features -- f1 score
display(HM.compare_models(models, ['optimized - f1' for _ in models], ['Health TFIDF' for _ in models],
                          tfs_h=True))
# Out:
#                 FN   FP    TN   TP  accuracy        f1       mse  precision  \
# sum_priority
# 1             2540  468  3630  409  0.573152  0.213800  0.426848   0.466363
# 2              895  613  5409  130  0.786008  0.147059  0.213992   0.174966
# 3              300  561  6152   34  0.877820  0.073197  0.122180   0.057143
# 4               91  232  6719    5  0.954165  0.030030  0.045835   0.021097
# 5               23  138  6886    0  0.977153  0.000000  0.022847   0.000000
# 6                7   30  7010    0  0.994750  0.000000  0.005250   0.000000
#
#                 recall                   model
# sum_priority
# 1             0.138691  RandomForestClassifier
# 2             0.126829  RandomForestClassifier
# 3             0.101796  RandomForestClassifier
# 4             0.052083  RandomForestClassifier
# 5             0.000000  RandomForestClassifier
# 6             0.000000  RandomForestClassifier

# %% [markdown]
# ## GRID SEARCH FOR BEST PARAMETERS

# %% [markdown]
# ### Random Forest Models:

# %%
RF = RandomForestClassifier()
param_grid_rfc = {
                'n_estimators':[100, 200],
                'criterion': ['gini','entropy'],
                'max_features': ['sqrt','log2'],
                'class_weight': ['balanced'],
                'max_depth': [2, 3, 4, 10],
                'min_samples_leaf': [2,3,4],
            }

# %% [markdown]
# ##### Original Summary Features

# %%
# %%time
HM.grid_search_classifier(RF, param_grid_rfc, col=col1, scoring='precision', t=2)
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 2,
#  'n_estimators': 200}

# %%
# %%time
HM.grid_search_classifier(RF, param_grid_rfc, col=col1, scoring='accuracy', t=2)
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 10,
#  'max_features': 'log2',
#  'min_samples_leaf': 2,
#  'n_estimators': 200}

# %%
# %%time
HM.grid_search_classifier(RF, param_grid_rfc, col=col1, scoring='recall', t=2)
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_depth': 2,
#  'max_features': 'log2',
#  'min_samples_leaf': 4,
#  'n_estimators': 100}

# %%
# %%time
HM.grid_search_classifier(RF, param_grid_rfc, col=col1, scoring='f1', t=2)
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 2,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 4,
#  'n_estimators': 200}

# %% [markdown]
# ##### Original Bag of Words (TFIDF, Vocab = Top 5000)

# %%
# %%time
HM.grid_search_classifier(RF, param_grid_rfc, tfs=True, scoring='precision', t=2)
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 10,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 3,
#  'n_estimators': 200}

# %%
# %%time
HM.grid_search_classifier(RF, param_grid_rfc, tfs=True, scoring='f1', t=2)
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 3,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 2,
#  'n_estimators': 200}

# %% [markdown]
# ##### Topic Summary Features

# %%
# %%time
HM.grid_search_classifier(RF, param_grid_rfc, col=col2, scoring='precision', t=2)
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 2,
#  'n_estimators': 200}

# %%
# %%time
HM.grid_search_classifier(RF, param_grid_rfc, col=col2, scoring='accuracy', t=2)
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 10,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 2,
#  'n_estimators': 200}

# %%
# %%time
HM.grid_search_classifier(RF, param_grid_rfc, col=col2, scoring='recall', t=2)
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 2,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 4,
#  'n_estimators': 100}

# %%
# %%time
HM.grid_search_classifier(RF, param_grid_rfc, col=col2, scoring='f1', t=2)
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 3,
#  'n_estimators': 100}

# %% [markdown]
# ##### Hygiene (Topic) Bag of Words (Vocab = Top 5000)

# %%
# %%time
HM.grid_search_classifier(RF, param_grid_rfc, tfs_h=True, scoring='precision', t=2)
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 3,
#  'max_features': 'log2',
#  'min_samples_leaf': 4,
#  'n_estimators': 200}

# %%
# %%time
HM.grid_search_classifier(RF, param_grid_rfc, tfs_h=True, scoring='f1', t=2)
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_depth': 2,
#  'max_features': 'log2',
#  'min_samples_leaf': 3,
#  'n_estimators': 100}

# %% [markdown]
# ### SVC Models

# %%
LSVC_C = np.logspace(-1, 0.5, 10)
param_grid_svc = {'loss': 'squared_hinge',
                  'penalty': 'l1',
                  'dual': False,
                  'random_state': 981}
models = [LinearSVC(C=c, **param_grid_svc) for c in LSVC_C]

# %%
LSVC_C2 = np.logspace(0.5, 1.5, 10)
models2 = [LinearSVC(C=c, **param_grid_svc) for c in LSVC_C2]

# %%
LSVC_C3 = np.logspace(1.5, 3, 10)
models3 = [LinearSVC(C=c, **param_grid_svc) for c in LSVC_C3]

# %% [markdown]
# ##### Original Summary Features

# %%
# %%time
display(HM.k_fold_comparison(models, [('C = %.4f' % c) for c in LSVC_C], 
                             ['Original Features' for _ in models], col=col1, val_range=[2]))
# Out:
#                FN  FP    TN  TP  accuracy  f1       mse  precision  recall  \
# sum_priority
# 2             770   0  4710   0  0.859489   0  0.140511          0       0
# 2             820   2  4658   0  0.850000   0  0.150000          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   0  4710   0  0.859489   0  0.140511          0       0
# 2             820   2  4658   0  0.850000   0  0.150000          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   0  4710   0  0.859489   0  0.140511          0       0
# 2             820   2  4658   0  0.850000   0  0.150000          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   0  4710   0  0.859489   0  0.140511          0       0
# 2             820   2  4658   0  0.850000   0  0.150000          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   0  4710   0  0.859489   0  0.140511          0       0
# 2             820   2  4658   0  0.850000   0  0.150000          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   0  4710   0  0.859489   0  0.140511          0       0
# 2             820   2  4658   0  0.850000   0  0.150000          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   0  4710   0  0.859489   0  0.140511          0       0
# 2             820   2  4658   0  0.850000   0  0.150000          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   0  4710   0  0.859489   0  0.140511          0       0
# 2             820   2  4658   0  0.850000   0  0.150000          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   0  4710   0  0.859489   0  0.140511          0       0
# 2             820   2  4658   0  0.850000   0  0.150000          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   0  4710   0  0.859489   0  0.140511          0       0
# 2             820   2  4658   0  0.850000   0  0.150000          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
#
#                   model        type           features  k-fold
# sum_priority
# 2             LinearSVC  C = 0.1000  Original Features       0
# 2             LinearSVC  C = 0.1000  Original Features       1
# 2             LinearSVC  C = 0.1000  Original Features       2
# 2             LinearSVC  C = 0.1468  Original Features       0
# 2             LinearSVC  C = 0.1468  Original Features       1
# 2             LinearSVC  C = 0.1468  Original Features       2
# 2             LinearSVC  C = 0.2154  Original Features       0
# 2             LinearSVC  C = 0.2154  Original Features       1
# 2             LinearSVC  C = 0.2154  Original Features       2
# 2             LinearSVC  C = 0.3162  Original Features       0
# 2             LinearSVC  C = 0.3162  Original Features       1
# 2             LinearSVC  C = 0.3162  Original Features       2
# 2             LinearSVC  C = 0.4642  Original Features       0
# 2             LinearSVC  C = 0.4642  Original Features       1
# 2             LinearSVC  C = 0.4642  Original Features       2
# 2             LinearSVC  C = 0.6813  Original Features       0
# 2             LinearSVC  C = 0.6813  Original Features       1
# 2             LinearSVC  C = 0.6813  Original Features       2
# 2             LinearSVC  C = 1.0000  Original Features       0
# 2             LinearSVC  C = 1.0000  Original Features       1
# 2             LinearSVC  C = 1.0000  Original Features       2
# 2             LinearSVC  C = 1.4678  Original Features       0
# 2             LinearSVC  C = 1.4678  Original Features       1
# 2             LinearSVC  C = 1.4678  Original Features       2
# 2             LinearSVC  C = 2.1544  Original Features       0
# 2             LinearSVC  C = 2.1544  Original Features       1
# 2             LinearSVC  C = 2.1544  Original Features       2
# 2             LinearSVC  C = 3.1623  Original Features       0
# 2             LinearSVC  C = 3.1623  Original Features       1
# 2             LinearSVC  C = 3.1623  Original Features       2
# CPU times: user 1.68 s, sys: 20.5 ms, total: 1.7 s
# Wall time: 1.71 s

# %% [markdown]
# ##### Original Bag of Words (TFIDF, Vocab = Top 5000)

# %%
# %%time
display(HM.k_fold_comparison(models, [('C = %.4f' % c) for c in LSVC_C], 
                             ['Original TFIDF' for _ in models], tfs=True, val_range=[2]))
# Out:
#                FN   FP    TN   TP  accuracy        f1       mse  precision  \
# sum_priority
# 2             770    0  4710    0  0.859489  0.000000  0.140511   0.000000
# 2             820    0  4660    0  0.850365  0.000000  0.149635   0.000000
# 2             784    0  4696    0  0.856934  0.000000  0.143066   0.000000
# 2             769    0  4710    1  0.859672  0.002594  0.140328   1.000000
# 2             820    0  4660    0  0.850365  0.000000  0.149635   0.000000
# 2             782    0  4696    2  0.857299  0.005089  0.142701   1.000000
# 2             769    0  4710    1  0.859672  0.002594  0.140328   1.000000
# 2             816    0  4660    4  0.851095  0.009709  0.148905   1.000000
# 2             780    1  4695    4  0.857482  0.010139  0.142518   0.800000
# 2             767    3  4707    3  0.859489  0.007732  0.140511   0.500000
# 2             812    1  4659    8  0.851642  0.019300  0.148358   0.888889
# 2             777    1  4695    7  0.858029  0.017677  0.141971   0.875000
# 2             766   13  4697    4  0.857847  0.010165  0.142153   0.235294
# 2             811    6  4654    9  0.850912  0.021557  0.149088   0.600000
# 2             771    6  4690   13  0.858212  0.032379  0.141788   0.684211
# 2             753   35  4675   17  0.856204  0.041363  0.143796   0.326923
# 2             809   16  4644   11  0.849453  0.025974  0.150547   0.407407
# 2             767   19  4677   17  0.856569  0.041463  0.143431   0.472222
# 2             738   87  4623   32  0.849453  0.071991  0.150547   0.268908
# 2             795   47  4613   25  0.846350  0.056054  0.153650   0.347222
# 2             749   76  4620   35  0.849453  0.078212  0.150547   0.315315
# 2             706  198  4512   64  0.835036  0.124031  0.164964   0.244275
# 2             774  157  4503   46  0.830109  0.089932  0.169891   0.226601
# 2             714  176  4520   70  0.837591  0.135922  0.162409   0.284553
# 2             662  354  4356  108  0.814599  0.175325  0.185401   0.233766
# 2             740  303  4357   80  0.809672  0.133001  0.190328   0.208877
# 2             677  319  4377  107  0.818248  0.176860  0.181752   0.251174
# 2             623  517  4193  147  0.791971  0.205021  0.208029   0.221386
# 2             697  469  4191  123  0.787226  0.174221  0.212774   0.207770
# 2             646  499  4197  138  0.791058  0.194229  0.208942   0.216641
#
#                 recall      model                     type        features  \
# sum_priority
# 2             0.000000  LinearSVC  grid search, C = 0.1000  Original TFIDF
# 2             0.000000  LinearSVC  grid search, C = 0.1000  Original TFIDF
# 2             0.000000  LinearSVC  grid search, C = 0.1000  Original TFIDF
# 2             0.001299  LinearSVC  grid search, C = 0.1468  Original TFIDF
# 2             0.000000  LinearSVC  grid search, C = 0.1468  Original TFIDF
# 2             0.002551  LinearSVC  grid search, C = 0.1468  Original TFIDF
# 2             0.001299  LinearSVC  grid search, C = 0.2154  Original TFIDF
# 2             0.004878  LinearSVC  grid search, C = 0.2154  Original TFIDF
# 2             0.005102  LinearSVC  grid search, C = 0.2154  Original TFIDF
# 2             0.003896  LinearSVC  grid search, C = 0.3162  Original TFIDF
# 2             0.009756  LinearSVC  grid search, C = 0.3162  Original TFIDF
# 2             0.008929  LinearSVC  grid search, C = 0.3162  Original TFIDF
# 2             0.005195  LinearSVC  grid search, C = 0.4642  Original TFIDF
# 2             0.010976  LinearSVC  grid search, C = 0.4642  Original TFIDF
# 2             0.016582  LinearSVC  grid search, C = 0.4642  Original TFIDF
# 2             0.022078  LinearSVC  grid search, C = 0.6813  Original TFIDF
# 2             0.013415  LinearSVC  grid search, C = 0.6813  Original TFIDF
# 2             0.021684  LinearSVC  grid search, C = 0.6813  Original TFIDF
# 2             0.041558  LinearSVC  grid search, C = 1.0000  Original TFIDF
# 2             0.030488  LinearSVC  grid search, C = 1.0000  Original TFIDF
# 2             0.044643  LinearSVC  grid search, C = 1.0000  Original TFIDF
# 2             0.083117  LinearSVC  grid search, C = 1.4678  Original TFIDF
# 2             0.056098  LinearSVC  grid search, C = 1.4678  Original TFIDF
# 2             0.089286  LinearSVC  grid search, C = 1.4678  Original TFIDF
# 2             0.140260  LinearSVC  grid search, C = 2.1544  Original TFIDF
# 2             0.097561  LinearSVC  grid search, C = 2.1544  Original TFIDF
# 2             0.136480  LinearSVC  grid search, C = 2.1544  Original TFIDF
# 2             0.190909  LinearSVC  grid search, C = 3.1623  Original TFIDF
# 2             0.150000  LinearSVC  grid search, C = 3.1623  Original TFIDF
# 2             0.176020  LinearSVC  grid search, C = 3.1623  Original TFIDF
#
#               k-fold
# sum_priority
# 2                  0
# 2                  1
# 2                  2
# 2                  0
# 2                  1
# 2                  2
# 2                  0
# 2                  1
# 2                  2
# 2                  0
# 2                  1
# 2                  2
# 2                  0
# 2                  1
# 2                  2
# 2                  0
# 2                  1
# 2                  2
# 2                  0
# 2                  1
# 2                  2
# 2                  0
# 2                  1
# 2                  2
# 2                  0
# 2                  1
# 2                  2
# 2                  0
# 2                  1
# 2                  2
# CPU times: user 1min 54s, sys: 43.7 s, total: 2min 38s
# Wall time: 2min 50s

# %%
# %%time
display(HM.k_fold_comparison(models2, [('C = %.4f' % c) for c in LSVC_C2], 
                             ['Original TFIDF' for _ in models2], tfs=True, val_range=[2]))
# Out:
#                FN   FP    TN   TP  accuracy        f1       mse  precision  \
# sum_priority
# 2             770    0  4710    0  0.859489  0.000000  0.140511   0.000000
# 2             820    0  4660    0  0.850365  0.000000  0.149635   0.000000
# 2             784    0  4696    0  0.856934  0.000000  0.143066   0.000000
# 2             769    0  4710    1  0.859672  0.002594  0.140328   1.000000
# 2             820    0  4660    0  0.850365  0.000000  0.149635   0.000000
# 2             782    0  4696    2  0.857299  0.005089  0.142701   1.000000
# 2             769    0  4710    1  0.859672  0.002594  0.140328   1.000000
# 2             816    0  4660    4  0.851095  0.009709  0.148905   1.000000
# 2             780    1  4695    4  0.857482  0.010139  0.142518   0.800000
# 2             767    3  4707    3  0.859489  0.007732  0.140511   0.500000
# 2             812    1  4659    8  0.851642  0.019300  0.148358   0.888889
# 2             777    1  4695    7  0.858029  0.017677  0.141971   0.875000
# 2             766   13  4697    4  0.857847  0.010165  0.142153   0.235294
# 2             811    6  4654    9  0.850912  0.021557  0.149088   0.600000
# 2             771    6  4690   13  0.858212  0.032379  0.141788   0.684211
# 2             753   35  4675   17  0.856204  0.041363  0.143796   0.326923
# 2             809   16  4644   11  0.849453  0.025974  0.150547   0.407407
# 2             767   19  4677   17  0.856569  0.041463  0.143431   0.472222
# 2             738   87  4623   32  0.849453  0.071991  0.150547   0.268908
# 2             795   47  4613   25  0.846350  0.056054  0.153650   0.347222
# 2             749   76  4620   35  0.849453  0.078212  0.150547   0.315315
# 2             706  198  4512   64  0.835036  0.124031  0.164964   0.244275
# 2             774  157  4503   46  0.830109  0.089932  0.169891   0.226601
# 2             714  176  4520   70  0.837591  0.135922  0.162409   0.284553
# 2             662  354  4356  108  0.814599  0.175325  0.185401   0.233766
# 2             740  303  4357   80  0.809672  0.133001  0.190328   0.208877
# 2             677  319  4377  107  0.818248  0.176860  0.181752   0.251174
# 2             623  517  4193  147  0.791971  0.205021  0.208029   0.221386
# 2             697  469  4191  123  0.787226  0.174221  0.212774   0.207770
# 2             646  499  4197  138  0.791058  0.194229  0.208942   0.216641
#
#                 recall      model         type        features  k-fold
# sum_priority
# 2             0.000000  LinearSVC   C = 3.1623  Original TFIDF       0
# 2             0.000000  LinearSVC   C = 3.1623  Original TFIDF       1
# 2             0.000000  LinearSVC   C = 3.1623  Original TFIDF       2
# 2             0.001299  LinearSVC   C = 4.0842  Original TFIDF       0
# 2             0.000000  LinearSVC   C = 4.0842  Original TFIDF       1
# 2             0.002551  LinearSVC   C = 4.0842  Original TFIDF       2
# 2             0.001299  LinearSVC   C = 5.2750  Original TFIDF       0
# 2             0.004878  LinearSVC   C = 5.2750  Original TFIDF       1
# 2             0.005102  LinearSVC   C = 5.2750  Original TFIDF       2
# 2             0.003896  LinearSVC   C = 6.8129  Original TFIDF       0
# 2             0.009756  LinearSVC   C = 6.8129  Original TFIDF       1
# 2             0.008929  LinearSVC   C = 6.8129  Original TFIDF       2
# 2             0.005195  LinearSVC   C = 8.7992  Original TFIDF       0
# 2             0.010976  LinearSVC   C = 8.7992  Original TFIDF       1
# 2             0.016582  LinearSVC   C = 8.7992  Original TFIDF       2
# 2             0.022078  LinearSVC  C = 11.3646  Original TFIDF       0
# 2             0.013415  LinearSVC  C = 11.3646  Original TFIDF       1
# 2             0.021684  LinearSVC  C = 11.3646  Original TFIDF       2
# 2             0.041558  LinearSVC  C = 14.6780  Original TFIDF       0
# 2             0.030488  LinearSVC  C = 14.6780  Original TFIDF       1
# 2             0.044643  LinearSVC  C = 14.6780  Original TFIDF       2
# 2             0.083117  LinearSVC  C = 18.9574  Original TFIDF       0
# 2             0.056098  LinearSVC  C = 18.9574  Original TFIDF       1
# 2             0.089286  LinearSVC  C = 18.9574  Original TFIDF       2
# 2             0.140260  LinearSVC  C = 24.4844  Original TFIDF       0
# 2             0.097561  LinearSVC  C = 24.4844  Original TFIDF       1
# 2             0.136480  LinearSVC  C = 24.4844  Original TFIDF       2
# 2             0.190909  LinearSVC  C = 31.6228  Original TFIDF       0
# 2             0.150000  LinearSVC  C = 31.6228  Original TFIDF       1
# 2             0.176020  LinearSVC  C = 31.6228  Original TFIDF       2
# CPU times: user 1min 59s, sys: 53.8 s, total: 2min 53s
# Wall time: 3min 14s

# %%
# %%time
display(HM.k_fold_comparison(models3, [('C = %.4f' % c) for c in LSVC_C3], 
                             ['Original TFIDF' for _ in models3], tfs=True, val_range=[2]))

# %% [markdown]
# ##### Topic Summary Features

# %%
# %%time
display(HM.k_fold_comparison(models, [('C = %.4f' % c) for c in LSVC_C], 
                             ['Topic Features' for _ in models], col=col2, val_range=[2]))
# Out:
#                FN  FP    TN  TP  accuracy  f1       mse  precision  recall  \
# sum_priority
# 2             770   3  4707   0  0.858942   0  0.141058          0       0
# 2             820   1  4659   0  0.850182   0  0.149818          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   3  4707   0  0.858942   0  0.141058          0       0
# 2             820   1  4659   0  0.850182   0  0.149818          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   3  4707   0  0.858942   0  0.141058          0       0
# 2             820   1  4659   0  0.850182   0  0.149818          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   3  4707   0  0.858942   0  0.141058          0       0
# 2             820   1  4659   0  0.850182   0  0.149818          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   3  4707   0  0.858942   0  0.141058          0       0
# 2             820   1  4659   0  0.850182   0  0.149818          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   3  4707   0  0.858942   0  0.141058          0       0
# 2             820   1  4659   0  0.850182   0  0.149818          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   3  4707   0  0.858942   0  0.141058          0       0
# 2             820   1  4659   0  0.850182   0  0.149818          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   3  4707   0  0.858942   0  0.141058          0       0
# 2             820   1  4659   0  0.850182   0  0.149818          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   3  4707   0  0.858942   0  0.141058          0       0
# 2             820   1  4659   0  0.850182   0  0.149818          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
# 2             770   3  4707   0  0.858942   0  0.141058          0       0
# 2             820   1  4659   0  0.850182   0  0.149818          0       0
# 2             784   0  4696   0  0.856934   0  0.143066          0       0
#
#                   model        type        features  k-fold
# sum_priority
# 2             LinearSVC  C = 0.1000  Topic Features       0
# 2             LinearSVC  C = 0.1000  Topic Features       1
# 2             LinearSVC  C = 0.1000  Topic Features       2
# 2             LinearSVC  C = 0.1468  Topic Features       0
# 2             LinearSVC  C = 0.1468  Topic Features       1
# 2             LinearSVC  C = 0.1468  Topic Features       2
# 2             LinearSVC  C = 0.2154  Topic Features       0
# 2             LinearSVC  C = 0.2154  Topic Features       1
# 2             LinearSVC  C = 0.2154  Topic Features       2
# 2             LinearSVC  C = 0.3162  Topic Features       0
# 2             LinearSVC  C = 0.3162  Topic Features       1
# 2             LinearSVC  C = 0.3162  Topic Features       2
# 2             LinearSVC  C = 0.4642  Topic Features       0
# 2             LinearSVC  C = 0.4642  Topic Features       1
# 2             LinearSVC  C = 0.4642  Topic Features       2
# 2             LinearSVC  C = 0.6813  Topic Features       0
# 2             LinearSVC  C = 0.6813  Topic Features       1
# 2             LinearSVC  C = 0.6813  Topic Features       2
# 2             LinearSVC  C = 1.0000  Topic Features       0
# 2             LinearSVC  C = 1.0000  Topic Features       1
# 2             LinearSVC  C = 1.0000  Topic Features       2
# 2             LinearSVC  C = 1.4678  Topic Features       0
# 2             LinearSVC  C = 1.4678  Topic Features       1
# 2             LinearSVC  C = 1.4678  Topic Features       2
# 2             LinearSVC  C = 2.1544  Topic Features       0
# 2             LinearSVC  C = 2.1544  Topic Features       1
# 2             LinearSVC  C = 2.1544  Topic Features       2
# 2             LinearSVC  C = 3.1623  Topic Features       0
# 2             LinearSVC  C = 3.1623  Topic Features       1
# 2             LinearSVC  C = 3.1623  Topic Features       2
# CPU times: user 4.94 s, sys: 94.7 ms, total: 5.04 s
# Wall time: 5.16 s

# %% [markdown]
# ##### Hygiene (Topic) Bag of Words (Vocab = Top 5000)

# %%
# %%time
display(HM.k_fold_comparison(models, [('C = %.4f' % c) for c in LSVC_C], 
                             ['Health TFIDF' for _ in models], tfs_h=True, val_range=[2]))
# Out:
#                FN   FP    TN  TP  accuracy        f1       mse  precision  \
# sum_priority
# 2             770    0  4710   0  0.859489  0.000000  0.140511   0.000000
# 2             820    0  4660   0  0.850365  0.000000  0.149635   0.000000
# 2             784    0  4696   0  0.856934  0.000000  0.143066   0.000000
# 2             770    0  4710   0  0.859489  0.000000  0.140511   0.000000
# 2             820    0  4660   0  0.850365  0.000000  0.149635   0.000000
# 2             784    0  4696   0  0.856934  0.000000  0.143066   0.000000
# 2             770    0  4710   0  0.859489  0.000000  0.140511   0.000000
# 2             820    0  4660   0  0.850365  0.000000  0.149635   0.000000
# 2             784    0  4696   0  0.856934  0.000000  0.143066   0.000000
# 2             770    3  4707   0  0.858942  0.000000  0.141058   0.000000
# 2             820    0  4660   0  0.850365  0.000000  0.149635   0.000000
# 2             784    1  4695   0  0.856752  0.000000  0.143248   0.000000
# 2             768    8  4702   2  0.858394  0.005128  0.141606   0.200000
# 2             819    1  4659   1  0.850365  0.002433  0.149635   0.500000
# 2             783    1  4695   1  0.856934  0.002545  0.143066   0.500000
# 2             767   18  4692   3  0.856752  0.007585  0.143248   0.142857
# 2             815   13  4647   5  0.848905  0.011933  0.151095   0.277778
# 2             782    8  4688   2  0.855839  0.005038  0.144161   0.200000
# 2             760   41  4669  10  0.853832  0.024361  0.146168   0.196078
# 2             809   36  4624  11  0.845803  0.025375  0.154197   0.234043
# 2             777   30  4666   7  0.852737  0.017052  0.147263   0.189189
# 2             754   67  4643  16  0.850182  0.037515  0.149818   0.192771
# 2             796   71  4589  24  0.841788  0.052459  0.158212   0.252632
# 2             765   62  4634  19  0.849088  0.043931  0.150912   0.234568
# 2             748  111  4599  22  0.843248  0.048726  0.156752   0.165414
# 2             789  113  4547  31  0.835401  0.064315  0.164599   0.215278
# 2             760  103  4593  24  0.842518  0.052689  0.157482   0.188976
# 2             739  141  4569  31  0.839416  0.065817  0.160584   0.180233
# 2             779  157  4503  41  0.829197  0.080550  0.170803   0.207071
# 2             752  139  4557  32  0.837409  0.067016  0.162591   0.187135
#
#                 recall      model        type      features  k-fold
# sum_priority
# 2             0.000000  LinearSVC  C = 0.1000  Health TFIDF       0
# 2             0.000000  LinearSVC  C = 0.1000  Health TFIDF       1
# 2             0.000000  LinearSVC  C = 0.1000  Health TFIDF       2
# 2             0.000000  LinearSVC  C = 0.1468  Health TFIDF       0
# 2             0.000000  LinearSVC  C = 0.1468  Health TFIDF       1
# 2             0.000000  LinearSVC  C = 0.1468  Health TFIDF       2
# 2             0.000000  LinearSVC  C = 0.2154  Health TFIDF       0
# 2             0.000000  LinearSVC  C = 0.2154  Health TFIDF       1
# 2             0.000000  LinearSVC  C = 0.2154  Health TFIDF       2
# 2             0.000000  LinearSVC  C = 0.3162  Health TFIDF       0
# 2             0.000000  LinearSVC  C = 0.3162  Health TFIDF       1
# 2             0.000000  LinearSVC  C = 0.3162  Health TFIDF       2
# 2             0.002597  LinearSVC  C = 0.4642  Health TFIDF       0
# 2             0.001220  LinearSVC  C = 0.4642  Health TFIDF       1
# 2             0.001276  LinearSVC  C = 0.4642  Health TFIDF       2
# 2             0.003896  LinearSVC  C = 0.6813  Health TFIDF       0
# 2             0.006098  LinearSVC  C = 0.6813  Health TFIDF       1
# 2             0.002551  LinearSVC  C = 0.6813  Health TFIDF       2
# 2             0.012987  LinearSVC  C = 1.0000  Health TFIDF       0
# 2             0.013415  LinearSVC  C = 1.0000  Health TFIDF       1
# 2             0.008929  LinearSVC  C = 1.0000  Health TFIDF       2
# 2             0.020779  LinearSVC  C = 1.4678  Health TFIDF       0
# 2             0.029268  LinearSVC  C = 1.4678  Health TFIDF       1
# 2             0.024235  LinearSVC  C = 1.4678  Health TFIDF       2
# 2             0.028571  LinearSVC  C = 2.1544  Health TFIDF       0
# 2             0.037805  LinearSVC  C = 2.1544  Health TFIDF       1
# 2             0.030612  LinearSVC  C = 2.1544  Health TFIDF       2
# 2             0.040260  LinearSVC  C = 3.1623  Health TFIDF       0
# 2             0.050000  LinearSVC  C = 3.1623  Health TFIDF       1
# 2             0.040816  LinearSVC  C = 3.1623  Health TFIDF       2
# CPU times: user 25.9 s, sys: 38.2 s, total: 1min 4s
# Wall time: 1min 12s

# %%
# %%time
display(HM.k_fold_comparison(models2, [('C = %.4f' % c) for c in LSVC_C2], 
                             ['Health TFIDF' for _ in models2], tfs_h=True, val_range=[2]))
# Out:
#                FN   FP    TN  TP  accuracy        f1       mse  precision  \
# sum_priority
# 2             770    0  4710   0  0.859489  0.000000  0.140511   0.000000
# 2             820    0  4660   0  0.850365  0.000000  0.149635   0.000000
# 2             784    0  4696   0  0.856934  0.000000  0.143066   0.000000
# 2             770    0  4710   0  0.859489  0.000000  0.140511   0.000000
# 2             820    0  4660   0  0.850365  0.000000  0.149635   0.000000
# 2             784    0  4696   0  0.856934  0.000000  0.143066   0.000000
# 2             770    0  4710   0  0.859489  0.000000  0.140511   0.000000
# 2             820    0  4660   0  0.850365  0.000000  0.149635   0.000000
# 2             784    0  4696   0  0.856934  0.000000  0.143066   0.000000
# 2             770    3  4707   0  0.858942  0.000000  0.141058   0.000000
# 2             820    0  4660   0  0.850365  0.000000  0.149635   0.000000
# 2             784    1  4695   0  0.856752  0.000000  0.143248   0.000000
# 2             768    8  4702   2  0.858394  0.005128  0.141606   0.200000
# 2             819    1  4659   1  0.850365  0.002433  0.149635   0.500000
# 2             783    1  4695   1  0.856934  0.002545  0.143066   0.500000
# 2             767   18  4692   3  0.856752  0.007585  0.143248   0.142857
# 2             815   13  4647   5  0.848905  0.011933  0.151095   0.277778
# 2             782    8  4688   2  0.855839  0.005038  0.144161   0.200000
# 2             760   41  4669  10  0.853832  0.024361  0.146168   0.196078
# 2             809   36  4624  11  0.845803  0.025375  0.154197   0.234043
# 2             777   30  4666   7  0.852737  0.017052  0.147263   0.189189
# 2             754   67  4643  16  0.850182  0.037515  0.149818   0.192771
# 2             796   71  4589  24  0.841788  0.052459  0.158212   0.252632
# 2             765   62  4634  19  0.849088  0.043931  0.150912   0.234568
# 2             748  111  4599  22  0.843248  0.048726  0.156752   0.165414
# 2             789  113  4547  31  0.835401  0.064315  0.164599   0.215278
# 2             760  103  4593  24  0.842518  0.052689  0.157482   0.188976
# 2             739  141  4569  31  0.839416  0.065817  0.160584   0.180233
# 2             779  157  4503  41  0.829197  0.080550  0.170803   0.207071
# 2             752  139  4557  32  0.837409  0.067016  0.162591   0.187135
#
#                 recall      model         type      features  k-fold
# sum_priority
# 2             0.000000  LinearSVC   C = 3.1623  Health TFIDF       0
# 2             0.000000  LinearSVC   C = 3.1623  Health TFIDF       1
# 2             0.000000  LinearSVC   C = 3.1623  Health TFIDF       2
# 2             0.000000  LinearSVC   C = 4.0842  Health TFIDF       0
# 2             0.000000  LinearSVC   C = 4.0842  Health TFIDF       1
# 2             0.000000  LinearSVC   C = 4.0842  Health TFIDF       2
# 2             0.000000  LinearSVC   C = 5.2750  Health TFIDF       0
# 2             0.000000  LinearSVC   C = 5.2750  Health TFIDF       1
# 2             0.000000  LinearSVC   C = 5.2750  Health TFIDF       2
# 2             0.000000  LinearSVC   C = 6.8129  Health TFIDF       0
# 2             0.000000  LinearSVC   C = 6.8129  Health TFIDF       1
# 2             0.000000  LinearSVC   C = 6.8129  Health TFIDF       2
# 2             0.002597  LinearSVC   C = 8.7992  Health TFIDF       0
# 2             0.001220  LinearSVC   C = 8.7992  Health TFIDF       1
# 2             0.001276  LinearSVC   C = 8.7992  Health TFIDF       2
# 2             0.003896  LinearSVC  C = 11.3646  Health TFIDF       0
# 2             0.006098  LinearSVC  C = 11.3646  Health TFIDF       1
# 2             0.002551  LinearSVC  C = 11.3646  Health TFIDF       2
# 2             0.012987  LinearSVC  C = 14.6780  Health TFIDF       0
# 2             0.013415  LinearSVC  C = 14.6780  Health TFIDF       1
# 2             0.008929  LinearSVC  C = 14.6780  Health TFIDF       2
# 2             0.020779  LinearSVC  C = 18.9574  Health TFIDF       0
# 2             0.029268  LinearSVC  C = 18.9574  Health TFIDF       1
# 2             0.024235  LinearSVC  C = 18.9574  Health TFIDF       2
# 2             0.028571  LinearSVC  C = 24.4844  Health TFIDF       0
# 2             0.037805  LinearSVC  C = 24.4844  Health TFIDF       1
# 2             0.030612  LinearSVC  C = 24.4844  Health TFIDF       2
# 2             0.040260  LinearSVC  C = 31.6228  Health TFIDF       0
# 2             0.050000  LinearSVC  C = 31.6228  Health TFIDF       1
# 2             0.040816  LinearSVC  C = 31.6228  Health TFIDF       2
# CPU times: user 25.9 s, sys: 37.9 s, total: 1min 3s
# Wall time: 1min 12s

# %%
# %%time
display(HM.k_fold_comparison(models3, [('C = %.4f' % c) for c in LSVC_C3], 
                             ['Health TFIDF' for _ in models3], tfs_h=True, val_range=[2]))
